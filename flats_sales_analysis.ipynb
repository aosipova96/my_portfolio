# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# <p></p>
#
# <div style="border:solid black 1px; padding: 20px">
#
# _____
# **Описание исходных данных:**
#
# Имеются данные сервиса Яндекс.Недвижимость - архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных.
# _____
# **Цель исследования:**
#
# Проанализировать и установить параметры объектов недвижимости и их влияние на стоимость, которые помогут построить автоматизированную систему для отслеживания аномалий и мошеннической деятельности.
# _____
# **Задачи исследования:**
#
# 1. Определить откуда приходят пользователи и какими устройствами они пользуются;
#
# _____
# Для достижения цели проекта и выполнения поставленных задач, **разделим исследование на несколько частей:**
#
# ***Часть 1. Изучаем общую информацию об имеющемся датасете***
#
# * [Импортируем необходимые библиотеки и изучаем общую информацию о данных;](#chapter_1)
# * [Изучаем основную статистическую информацию числовых параметров;](#chapter_2)
# * [Строим общую гистограмму для всех числовых столбцов;](#chapter_3)
#
# ***Часть 2. Выполняем предобработку данных***
#
# * [Переименовываем столбцы;](#chapter_4)
# * [Избавляемся от неявных дубликатов в названиях населенных пунктов;](#chapter_5)
# * [Проверяем датасет на наличие явных дубликатов;](#chapter_6)
# * [Изучаем и заполняем пропущенные значения в столбцах;](#chapter_7)
# * [Добавляем столбец с ценой одного квадратного метра;](#chapter_8)
# * [Добавляем столбец с днем публикации объявления;](#chapter_9)
# * [Добавляем столбцы с месяцем и годом публикации объявления;](#chapter_10)
# * [Создаем столбец с типом этажа;](#chapter_11)
# * [Создаем столбец с расстоянием до центра в километрах;](#chapter_12)
#
# ***Часть 3. Исследовательский анализ данных***
#
# * [Изучаем данные об общей площади квартир, строим гистограмму;](#chapter_13)
# * [Изучаем данные о площади кухни, строим гистограмму;](#chapter_14)
# * [Изучаем данные о цене, строим гистограмму;](#chapter_15)
# * [Изучаем данные о количестве комнат, строим гистограмму;](#chapter_16)
# * [Изучаем данные о высоте потолков, строим гистограмму;](#chapter_17)
# * [Изучаем данные об этаже квартиры и типе этажа, а также общее количество этажей в доме;](#chapter_18)
# * [Изучаем данные о расстоянии до центра города, до ближайшего аэропорта и до ближайшего парка;](#chapter_19)
# * [Изучаем данные с днем и месяцем публикации объявления;](#chapter_20)
# * [Изучаем данные количестве дней публикации объявления (скорости продажи);](#chapter_21)
# * [Рассчитываем корреляцию Пирсона с ценой для колличественных переменных, строим графики;](#chapter_22)
# * [Изучаем зависимость цены от категориальных переменных;](#chapter_23)
# * [Рассчитываем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений;](#chapter_24)
# * [Рассчитываем среднюю цену каждого километра в Санкт-Петербурге;](#chapter_25)
#
# ***[Формулируем общий вывод исследования](#chapter_26)***
# </div>
# <p></p>

# %% [markdown]
# <div style = "border:solid green 3px; padding:20px">
#
# Цель проекта - выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
# В ходе выполнения проекта на стадии предобработки данных были заполнены все пропущенные значения там, где это возможно. А так же были устранены неявные дубликаты и аномальные значения в каждом столбце. Было определено, что в исходных данных присутствуют квартиры люкс-сегмента (т.е. очень большие и дорогие).
#
# Выяснили, что большинство квартир имеют <b>1-2 комнаты</b>, общую площадь <b>от 30 до 50 кв.м метров</b>, средняя цена варьируется <b>от 3,5 до 6 млн.рублей</b>. Расположено большинство квартир преимущественно <b>с 1 по 5 этаж</b>, а дома, в основном, <b>5-ти и 9-ти этажные</b>.
#
# Объявления публикуются в основном в <b>будние дни</b>. В летние месяцы, а так же в декабре, январе и мае объявлений меньше.
#
# Рассмотрели какие факторы больше всего влияют на цену продажи и определили, что <b>общая площадь квартиры</b> сильнее всего влияет на цену. Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Самый дорогой квадратный метр в городах <b>Пушкин и Санкт-Петербург</b>, самый дешевый - в <b>Выборге</b>.
#
# Определили среднюю цену одного километра в Санкт-Петербурге, самый дорогой километр - <b>первый от центра города</b>, его цена в несколько раз превышает последующие километры.
#
# <div/>

# %% [markdown]
# ### Часть 1. Открываем файлы и изучаем общую информацию.

# %% [markdown]
# <a id='chapter_1'></a> Для начала импортируем все необходимые библиотеки.

# %%
import pandas as pd #импортируем библиотеку Pandas

import matplotlib.pyplot as plt #импортируем модуль pyplot библиотеки matplotlib

# %% [markdown]
# Прочитаем датасет с данными об объектах недвижимости.

# %%
# устанавливаем отображение всех столбцов
pd.options.display.max_columns = None 

# читаем файл real_estate_data
data = pd.read_csv('real_estate_data.csv', sep='\t')

# выводим 5 первых строк таблицы
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# После первого чтения файла увидели, что разделителем столбцов в таблице является символ '\t', поэтому при чтении файла был установлен соответствующий параметр sep='\t'

# %% [markdown]
# Посмотрим на размер данных, названия признаков и их типы.

# %%
# выводим размер датафрейма
data.shape
# Out:
# (23699, 22)

# %% [markdown]
# В исходных данных **23699** строк и **22** столбца. Теперь посмотрим общую информацию по датафрейму.

# %%
 # выводим общую информацию по датафрейму
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Видим, что в таблице 4 типа признаков. 2 столбца логического типа *bool*, 14 столбцов типа *float64*, 3 столбца типа *int64* и 3 столбца типа *object*. Большое количество столбцов имеет *пропуски в данных*.

# %% [markdown]
# * **airports_nearest** — расстояние до ближайшего аэропорта в метрах (м)
# * **balcony** — число балконов
# * **ceiling_height** — высота потолков (м)
# * **cityCenters_nearest** — расстояние до центра города (м)
# * **days_exposition** — сколько дней было размещено объявление (от публикации до снятия)
# * **first_day_exposition** — дата публикации
# * **floor** — этаж
# * **floors_total** — всего этажей в доме
# * **is_apartment** — апартаменты (булев тип)
# * **kitchen_area** — площадь кухни в квадратных метрах (м²)
# * **last_price** — цена на момент снятия с публикации
# * **living_area** — жилая площадь в квадратных метрах (м²)
# * **locality_name** — название населённого пункта
# * **open_plan** — свободная планировка (булев тип)
# * **parks_around3000** — число парков в радиусе 3 км
# * **parks_nearest** — расстояние до ближайшего парка (м)
# * **ponds_around3000** — число водоёмов в радиусе 3 км
# * **ponds_nearest** — расстояние до ближайшего водоёма (м)
# * **rooms** — число комнат
# * **studio** — квартира-студия (булев тип)
# * **total_area** — общая площадь квартиры в квадратных метрах (м²)
# * **total_images** — число фотографий квартиры в объявлении

# %% [markdown]
# <a id='chapter_2'></a> Посмотрим основные статистические характеристики числовых параметров методом describe.

# %%
# выводим транспонированную таблицу основных статистических характеристик
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# Видим, что в столбце **last_price** есть неправдоподобно маленькое значение - минимум - **12190** и очень большое значение - максимум - **763 млн.руб.** В столбце **total_area** также есть очень большое значение - **900 кв.м.** и очень маленькое - **12 кв.м.** Соответственно в **living_area** и **kitchen_area** есть достаточно большие значения. Так же есть аномально высокое значение в столбце **ceiling_height** - **100 метров** и аномальное маленькое - **1 метр**. В столбце **floors_total** есть аномальное значение - **60 этажей**, что маловероятно. Значения остальных столбцов выглядят весьма правдоподобно.

# %% [markdown]
# <a id='chapter_3'></a> Построим общую гистограмму для всех числовых столбцов таблицы.

# %%
# строим гистограмму размером 15 на 20:
data.hist(figsize=(15,20));

# %% [markdown]
# Видим, что не все гистограммы являются информативными, для получения более точной информации нужно выбирать количество корзин для каждой гистограммы отдельно. По текущим графиками можно заметить, например, что большинство квартир находятся на нижних этажах, чем выше этаж - тем меньше таких объявлений. Также видим, что большинство квартир имеют близость к водоему около 250-700 метров. Более подробно каждую гистограмму рассмотрим позднее.

# %% [markdown]
# ### Часть 2. Предобработка данных.

# %% [markdown]
# <a id='chapter_4'></a>Сначала изменим названия некоторых столбцов на более правильные.

# %%
# переименуем столбцы с помощью метода rename()
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest', 
                            'parks_around3000':'parks_around_3000', 
                            'ponds_around3000':'ponds_around_3000'})

# %% [markdown]
# <a id='chapter_5'></a> Теперь посмотрим на неявные дубликаты в названиях населенных пунктов, т.к. это может помешать при удалении пропусков в данных. Выведем все уникальные значения столбца **locality_name**.

# %%
# выведем все уникальные значения столбца locality_name
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Можно заметить, что есть неявные дубликаты в словах *'посёлок'* и *'поселок'*. Их достаточно много. Заменим все буквы *'ё'* на *'е'*.

# %%
# заменяем букву ё на букву е в столбце locality_name
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

# %% [markdown]
# Также нужно удалить все неявные дубликаты по типу *'поселок городского типа Рябово'* и *'поселок Рябово'*. Значений достаточно много и искать их все вручную тяжело. Поэтому просто избавимся от типов населенных пунктов, такие как деревня, поселок, городской поселок и т.д.

# %%
# создадим список с наименованиями типов населенных пунктов
list_of_locality = ['поселок городского типа ', 'городской поселок ', 'коттеджный поселок ', 
                    'садовое товарищество ', 'поселок при железнодорожной станции ',
                    'садоводческое некоммерческое товарищество ', 'поселок ', 'село ', 'деревня ']

# передадим этот список как параметр методу replace и заменим эти значения в столбце locality_name на пустую строку
data['locality_name'] = data['locality_name'].replace(list_of_locality, '', regex=True)

# %% [markdown]
# <a id='chapter_6'></a>Проверим датасет на явные дубликаты (полностью повторяющиеся строки).

# %%
# ищем число строк, для которых метод duplicated() возвращает True
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <a id='chapter_7'></a>Полностью повторяющихся строк нет. Теперь найдем в каких столбцах имеются пропуски и сколько там таких пропусков.

# %%
#найдем сумму всех пропусков в таблице
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Многие столбцы имеют пропуски в данных, причем достаточно весомые. Так, например, столбец **is_apartment** имеет 20924 пустых строки из 23699. Также много пропусков в столбцах **park_nearest** и **ponds_nearest**. Пропуски в столбце **balcony** можно заменить на нули, т.к. скорее всего продавец не указал их наличие, т.к. их нет в квартире.

# %%
# присваиваем текущим значениям столбца новые значения с учетом заполненных пропусков
data['balcony'] = data['balcony'].fillna(0)

# выводим количество пустых значений в столбце
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Столбец **balcony** имеет тип данных *float64*, но количество балконов не может быть дробным числом, поэтому изменим тип столбца на int64.

# %%
# перезаписываем значения столбца balcony на значения с измененным типом
data['balcony'] = data['balcony'].astype('int64')

# %% [markdown]
# Рассмотрим столбец **is_apartment**. Посмотрим сколько всего уникальных значений есть в этом столбце.

# %%
# выводим уникальные непустые значения столбца и количество таких значений
data['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Видим, что из почти 24 тысяч записей *непустое* значение имеют лишь **2775** строк. С формальной точки зрения апартаменты — это нежилые, но по характеристикам и удобствам практически не уступающие квартирам помещения, в которых можно жить. Основным отличием является то, что в них нельзя зарегистрироваться. Апартаменты так же могут иметь несколько комнат, балкон и находиться как в центре, так и вне его. Поэтому нет смысла искать взаимосвязь этого параметра с другими параметрами в таблице для заполнения пропусков. Скорее всего, в этом столбце пропуск равносилен **False**, т.е. квартира не является апартаментами. Заполним пропуски.

# %%
# перезаписываем значения столбца на значения с заполненными пропусками
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# Проверим, что все пропуски заполнены.

# %%
# ищем количество пропусков в столбце is_apartment
data['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# Столбец **is_apartment** имеет тип *object*, изменим его на булев тип, т.к. значениями столбца являются только True и False.

# %%
# меняем тип данных на bool
data['is_apartment'] = data['is_apartment'].astype('bool')

# %% [markdown]
# Рассмотрим столбцы **parks_around_3000** и **ponds_around_3000**. Данные столбцы имеют по 5518 пропусков. Вероятнее всего, большинство пропусков в этих столбцах связано с тем, что квартиры находятся в маленьких пригородных городах или поселках, в которых нет ни прудов, ни парков. Получим список с названиями населенных пунктов, в которых для столбцов **parks_around_3000** и **ponds_around_3000** отсутствуют значения.

# %%
# находим срез датафрейма с условием, что в столбцах parks_around_3000 или ponds_around_3000 есть пропуски
(data.query('parks_around_3000.isna() == True or ponds_around_3000.isna() == True')['locality_name']
     .value_counts() # находим список уникальных значений в столбце locality_name
     .head(10))
# Out:
# Мурино             588
# Кудрово            472
# Всеволожск         398
# Гатчина            307
# Выборг             237
# Новое Девяткино    144
# Сертолово          142
# Кириши             125
# Бугры              114
# Сланцы             112
# Name: locality_name, dtype: int64

# %% [markdown]
# Видим, что, в основном, это, действительно, небольшие города и поселки в Ленинградской области. Будем считать, что на расстоянии 3 км вблизи продаваемых квартир нет парков или прудов. Заменим пропущенные значения в этих столбцах на нули.

# %%
# перезаписываем значения столбцов parks_around_3000 и ponds_around_3000 на значения с нулями вместо пропусков
data['parks_around_3000'] = data['parks_around_3000'].fillna(0)

data['ponds_around_3000'] = data['ponds_around_3000'].fillna(0)

# %% [markdown]
# Проверим, что пропусков в этих столбцах больше нет.

# %%
# суммируем пропущенные значения в столбце parks_around_3000
print(f'Сумма пропусков в столбце parks_around_3000 - {data["parks_around_3000"].isna().sum()}')

# суммируем пропущенные значения в столбце ponds_around_3000
print(f'Сумма пропусков в столбце ponds_around_3000 - {data["ponds_around_3000"].isna().sum()}')
# Out:
# Сумма пропусков в столбце parks_around_3000 - 0
# Сумма пропусков в столбце ponds_around_3000 - 0

# %% [markdown]
# Теперь изменим тип значений этих столбцов на целочисленный, т.к. количество прудов или парков не может быть вещественным числом.

# %%
# присваиваем столбцам parks_around_3000 и ponds_around_3000 значения с измененным типом данных
data['parks_around_3000'] = data['parks_around_3000'].astype('int64')

data['ponds_around_3000'] = data['ponds_around_3000'].astype('int64')

# %% [markdown]
# Теперь рассмотрим пропуски в столбцах **park_nearest** и **ponds_nearest**. Скорее всего, пропуски в этих столбцах связаны со значениями в соседних столбцах **parks_around_3000** и **ponds_around_3000** - парки и пруды в радиусе 3 км. Проверим это. Заполним пропуски в столбцах **park_nearest** и **ponds_nearest** нулями в тех строках, в которых значения столбцов **parks_around_3000** и **ponds_around_3000** также нулевые. Будем считать, что если парков и прудов нет в пределах 3 км, значит, поблизости их нет.

# %%
# выберем только те записи, в которых значения столбцов parks_around_3000 и ponds_around_3000 нулевые,
# заполняем нулями соответствующие значения столбца parks_nearest
data['parks_nearest'] = data.query('parks_around_3000 == 0')['parks_nearest'].fillna(0) 

# заполняем нулями соответствующие значения столбца ponds_nearest 
data['ponds_nearest'] = data.query('ponds_around_3000 == 0')['ponds_nearest'].fillna(0)

# %% [markdown]
# Проверяем сколько пропусков осталось в этих столбцах.

# %%
# ищем сумму пропущенных значений в столбце parks_nearest
print(f'Сумма пропусков в столбце parks_nearest - {data["parks_nearest"].isna().sum()}')

# ищем сумму пропущенных значений в столбце ponds_nearest
print(f'Сумма пропусков в столбце ponds_nearest - {data["ponds_nearest"].isna().sum()}')
# Out:
# Сумма пропусков в столбце parks_nearest - 8075
# Сумма пропусков в столбце ponds_nearest - 9110

# %% [markdown]
# У нас остались пустыми значения столбцов **parks_nearest** и **ponds_nearest** для которых в соответствующих столбцах **parks_around_3000** и **ponds_around_3000** значения не нулевые и не пустые. Т.к. значения в этих столбцах картографические, т.е. заполняются автоматически в зависимости от адреса квартиры, то, скорее всего, оставшиеся пропуски связаны с тем, что эти квартиры находятся в маленьких городах, где нет обозначенных парков или прудов. Логически заполнить эти значения не получится, да и они вряд ли понадобятся нам для дальнейшего анализа. Достаточно будет параметров **parks_around_3000** и **ponds_around_3000**. Поэтому сделаем эти значения нулевыми. И сразу же изменим тип данных на челочисленный, т.к. точность до сантиметров нам не нужна.

# %%
#перезаписываем значение на значения с 0 вместо пропуска и меняем тип значений:
data['parks_nearest'] = data['parks_nearest'].fillna(0).astype('int64')

data['ponds_nearest'] = data['ponds_nearest'].fillna(0).astype('int64')

# %% [markdown]
# Проверяем, что в **parks_nearest** и в **ponds_nearest** нет пропусков.

# %%
# находим сумму пропущенных значений в столбце parks_nearest
print(f'Сумма пропусков в столбце parks_nearest - {data["parks_nearest"].isna().sum()}')

# находим сумму пропущенных значений в столбце ponds_nearest
print(f'Сумма пропусков в столбце ponds_nearest - {data["ponds_nearest"].isna().sum()}')
# Out:
# Сумма пропусков в столбце parks_nearest - 0
# Сумма пропусков в столбце ponds_nearest - 0

# %% [markdown]
# Теперь рассмотрим параметры **airports_nearest** и **city_centers_nearest**. Начнем с **airports_nearest**. Найдем названия населенных пунктов, в которых есть непустые значения в этом столбце. Создадим список с названиями таких населенных пунктов.

# %%
# считаем количество строк для каждого уникального значения столбца locality_name
# для которого выполняется условие, что значение столбца airports_nearest не пустое
data_airport_exist = (data.query('airports_nearest.isna() == False')['locality_name']
                          .value_counts())

data_airport_exist
# Out:
# Санкт-Петербург    15636
# Шушары               436
# Пушкин               369
# Колпино              337
# Парголово            327
# Петергоф             201
# Сестрорецк           183
# Красное Село         176
# Ломоносов            132
# Кронштадт             95
# Металлострой          66
# Стрельна              44
# Павловск              38
# Зеленогорск           24
# Понтонный             20
# Саперный               6
# Молодежное             5
# Песочный               4
# Репино                 4
# Лисий Нос              3
# Александровская        2
# Мурино                 2
# Усть-Ижора             2
# Петро-Славянка         1
# Щеглово                1
# Левашово               1
# Белоостров             1
# Name: locality_name, dtype: int64

# %% [markdown]
# Мы нашли список с названиями населенных пунктов, для которых хотя бы один раз указано расстояние до аэропорта. Можно отметить, что все эти населенные пункты находятся в каком-либо районе города Санкт-Петербурга, т.е. входят в его состав. Кроме Мурино и Щеглово, эти города относятся к ЛО. Для Мурино у нас есть всего два непустых значения, а всего строк с квартирами в этом городе - **590**. То же самое и для Щеглово - у нас есть всего одного непустое значение, а всего строк - **24**. Заполнять пустые значения для квартир в этих городах по такому количеству данных будет неверно. Теперь мы сможем заполнить пустые значения столбца **airports_nearest** медианными значениями расстояния до аэропорта для каждого населенного пункта отдельно, за исключением Мурино и Щеглово. Пропуски в этих столбцах корректнее заполнить нулями.

# %%
#перебираем каждое уникальное значение столбца locality_name
for locality in data['locality_name'].unique():
    
    # проверяем условие, что текущее значение есть в списке с названиями населенных пунктов,
    # в которых есть данные о расстоянии до аэропорта
    # за исключением Мурино и Щеглово
    if locality in data_airport_exist and locality != ['Мурино', 'Щеглово']: 
        
        # выбираем строки, для которых значение в столбце locality_name равно текущему locality 
        # и в столбце airports_nearest пропуск
        data.loc[(data['locality_name'] == locality)&(data['airports_nearest'].isna()), 'airports_nearest'] = \
        data.loc[data['locality_name'] == locality, 'airports_nearest'].median() 
        # находим медиану значений столбца airports_nearest для строк, в которых значение столбца locality_name равно текущему

# %% [markdown]
# Теперь найдем список с названиями населенных пунктов, в которых ни для одного объявления не указано расстояние до аэропорта. Значит, скорее всего, аэропорт находится достаточно далеко. Тогда будем считать, что данный критерий существенно не повлияет на цену квартиры. Заполним пропуски в этих строках нулевыми значениями.

# %%
# делаем срез с условием, что в столбце airports_nearest - пропуск, выбираем столбец locality_name
# и считаем кол-во уникальных значений
data.query('airports_nearest.isna() == True')['locality_name'].value_counts()
# Out:
# Кудрово            472
# Всеволожск         398
# Гатчина            307
# Выборг             237
# Новое Девяткино    144
#                   ...
# Цвылево              1
# Курковицы            1
# Кривко               1
# Жилпоселок           1
# Дзержинского         1
# Name: locality_name, Length: 281, dtype: int64

# %%
# заполняем пропуски в столбце airports_nearest нулями
data['airports_nearest'] = data['airports_nearest'].fillna(0)

# %% [markdown]
# Проверим, что в столбце **airports_nearest** не осталось пропусков.

# %%
# считаем количество пропусков в столбце airports_nearest
data['airports_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Изменим тип данных с вещественного на целочисленный, т.к. точность до сантиметров нам не нужна.

# %%
# присваиваем столбцу новые значения с измененным типом данных
data['airports_nearest'] = data['airports_nearest'].astype('int64')

# %% [markdown]
# Теперь заполним пропуски в столбце **city_centers_nearest**. Максимальное значение в этом столбце 65968 м., минимальное - 181 м. Создадим датафрейм, в котором будут только строки, для которых указано расстояние до центра города.

# %%
#оставляем только строки, для которых значение столбца city_centers_nearest непустое
data_city_center = data.query('city_centers_nearest.isna() == False')['locality_name'].value_counts()

data_city_center
# Out:
# Санкт-Петербург    15660
# Шушары               436
# Пушкин               368
# Колпино              337
# Парголово            327
# Петергоф             201
# Сестрорецк           183
# Красное Село         176
# Ломоносов            132
# Кронштадт             95
# Металлострой          66
# Стрельна              44
# Павловск              38
# Зеленогорск           24
# Понтонный             20
# Саперный               6
# Молодежное             5
# Песочный               4
# Репино                 4
# Лисий Нос              3
# Александровская        2
# Мурино                 2
# Усть-Ижора             2
# Петро-Славянка         1
# Щеглово                1
# Левашово               1
# Белоостров             1
# Name: locality_name, dtype: int64

# %% [markdown]
# Для наглядности составим сводную таблицу по значениям столбца **locality_name**, и найдем количество строк, в которых указано расстояние до центра, максимальное и минимальное значение для каждого города и медиану.

# %%
# делаем срез данных из строк, в которых есть хотя бы одно значение в столбце city_centers_nearest
data_city_centers = data.query('city_centers_nearest.isna() == False') 

# создаем сводную таблицу по отфильтрованным данным по названию населенного пункта
# считаем количество, максимум, минимуму и медиану для столбца city_centers_nearest
data_city_centers.pivot_table(index='locality_name', 
                              values='city_centers_nearest', 
                              aggfunc=['count', max, min, 'median'])
# Out:
#                                count                  max  \
#                 city_centers_nearest city_centers_nearest
# locality_name
# Александровская                    2              27584.0
# Белоостров                         1              38868.0
# Зеленогорск                       24              62706.0
# Колпино                          337              37477.0
# Красное Село                     176              41792.0
# Кронштадт                         95              51511.0
# Левашово                           1              25727.0
# Лисий Нос                          3              28246.0
# Ломоносов                        132              61495.0
# Металлострой                      66              29217.0
# Молодежное                         5              65968.0
# Мурино                             2              21888.0
# Павловск                          38              36445.0
# Парголово                        327              24415.0
# ...

# %% [markdown]
# Судя по значениям, для этих населенных пунктов указано расстояние до центра Санкт-Петербурга, а не до центра самого города. Плюс ко всему, проанализировав, в каких населенных пунктах есть данные по расстоянию до центра города, можно отметить, что все эти населенные пункты находятся в каком-либо районе города Санкт-Петербурга, т.е. входят в его состав. Кроме Мурино и Щеглово. Для Мурино у нас есть всего два значения, причем одианковых, возможно, эти квартиры находятся в одном доме. По аналогии с удаленностью до аэропорта заполним пустые значения в столбце **city_centers_nearest** медианными для каждого города, только исключив из этого списка Мурино и Щеглово, т.к. заполнять пропуски в большом количестве строк значениями из пары строк не совсем корректно.

# %%
# перебираем уникальные значения из столбца locality_name:
for locality in data['locality_name'].unique():
    
    # выбираем только значения из отфильтрованного списка data_city_center, которые не равны Мурино и Щеглово:
    if locality in data_city_center and locality != ['Мурино', 'Щеглово']:
        
        # в которых значение locality_name равно текущему и в столбце city_centers_nearest пропуск
        data.loc[(data['locality_name'] == locality)&(data['city_centers_nearest'].isna()), 'city_centers_nearest'] = \
        data.loc[(data['locality_name'] == locality), 'city_centers_nearest'].median() 
        # заменяем это значение на медианное для текущего населенного пункта

# %% [markdown]
# Составим список с наименованиями населенных пунктов, в которых нет ни одного значения расстояния до центра города.

# %%
# считаем количество строк для каждого уникального значения столбца locality_name
# для которого выполняется условие, что значение столбца city_centers_nearest пустое
(data.query('city_centers_nearest.isna() == True')['locality_name']
     .value_counts()
     .head(20))
# Out:
# Кудрово            472
# Всеволожск         398
# Гатчина            307
# Выборг             237
# Новое Девяткино    144
# Сертолово          142
# Кириши             125
# Бугры              114
# Сланцы             112
# Волхов             111
# Кингисепп          104
# Тосно              104
# Никольское          94
# Коммунар            89
# Сосновый Бор        87
# Кировск             84
# Отрадное            80
# Янино-1             68
# Приозерск           66
# Старая              64
# Name: locality_name, dtype: int64

# %% [markdown]
# Видим, что, вероятнее всего, оставшиеся пустые значения в столбце **city_centers_nearest** - это строки для населённых пунктов, относящихся к Ленинградской области, поэтому для них не указаны расстояния до центра Петербурга и это не оказывает существенного влияния на цену. Заполним эти значения нулями и изменим тип данных на целочисленный, т.к. точность до сантиметров здесь не нужна.

# %%
# заполняем пропуски нулем
data['city_centers_nearest'] = data['city_centers_nearest'].fillna(0).astype('int64')

# %% [markdown]
# Проверим, что все пропуски в столбце заполнены.

# %%
# находим сумму пропущенных значений в столбце city_centers_nearest
data['city_centers_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Теперь рассмотрим пропуски в столбце **ceiling_height**. Выведем основные статистические характеристики для этого столбца.

# %%
# выводим основные статистические характеристики
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Отметим, что в данном столбце наверняка имеются выбросы, т.к. максимальное значение - **100 м.**, что вряд ли может быть. Построим *boxplot* для значений этого столбца.

# %%
# строим боксплот по столбцу ceiling_height
data.boxplot('ceiling_height', figsize=(8,6))

# установим предел значений по оси y для более читабельного отображения графика
plt.ylim(0, 40) 

# выводим название графика
plt.title('Ящик с усами для высоты потолков')

# задаем подпись оси Y
plt.ylabel('Высота потолков')

# отображаем полученный график
plt.show()

# строим боксплот по столбцу ceiling_height
data.boxplot('ceiling_height', figsize=(8,6))

# установим предел значений по оси y для более читабельного отображения графика
plt.ylim(0, 5) 

# задаем подпись оси Y
plt.ylabel('Высота потолков')

# отображаем полученный график
plt.show();

# %% [markdown]
# По графику видим, что есть большое количество выбросов - это потолки от 5 метров и выше. Даже в старом фонде Санкт-Петербурга высота потолков редко превышает 5 метров. Также в столбце есть значения от 20 до почти 33 метров. Здесь наверняка ошибка в порядке значений, их необходимо будет уменьшить на порядок. Примем минимальную величину потолка - 2.4 метра. Тогда мы будем уменьшать на порядок все значения больше 24. Еще есть одно очень большое значение - 100 м. Строку с этим значением можно будет удалить.

# %%
# перебираем каждое значение столбца ceiling_height
for ceil in data['ceiling_height']: 
    
# выбираем значения больше или равные 24м метрам   
    if ceil >= 24:
        
        # делим каждое значение на 10
        data.loc[data['ceiling_height'] == ceil, 'ceiling_height'] = \
        data.loc[data['ceiling_height'] == ceil, 'ceiling_height']/10

# %% [markdown]
# После приведения чисел к одному порядку еще раз выведем статистические показатели столбца **ceiling_height**.

# %%
# выводим основные статистические характеристики столбца ceiling_height
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.732251
# std          0.387344
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         22.600000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видим, что у нас по-прежнему имеются аномальные значения, например, высота потолка - **1 метр** или **22.6 метров**. Однако, среднее отклонение достаточно небольшое - **0.39**, что говорит о том, что таких выбросов немного. Медиана - **2.65 метров**, что тоже вполне похоже на правду. Выведем все строки с аномальными значениями, то есть у которых высота потолка ниже 2.4 метров и выше 5 метров.

# %%
# выбираем строки, для которых значение столбца ceiling_height меньше 2.4 или больше или равно 5 метрам,
# и отсортируем таблицу по убыванию цены last_price 
data.query('ceiling_height < 2.4 or ceiling_height >= 5.0').sort_values('last_price', ascending=False)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 1026             20  155000000.0      310.00  2018-10-12T00:00:00      5
# 20264            17  119000000.0      187.60  2017-07-10T00:00:00      4
# 464              15   66571000.0      280.30  2015-06-11T00:00:00      6
# 1388             20   59800000.0      399.00  2015-01-21T00:00:00      5
# 7578             17   38000000.0      143.00  2017-11-02T00:00:00      3
# 22869             0   15000000.0       25.00  2018-07-25T00:00:00      1
# 16446             6   12300000.0       88.30  2019-03-12T00:00:00      3
# 21227             0    8200000.0       71.00  2017-07-21T00:00:00      0
# 17496            15    6700000.0       92.90  2019-02-19T00:00:00      3
# 22590            16    6000000.0       55.00  2018-10-31T00:00:00      2
# 20507            12    5950000.0       60.00  2018-02-19T00:00:00      2
# 5863             20    5650000.0       45.00  2018-08-15T00:00:00      1
# ...

# %% [markdown]
# Видим, что в самом начале списка расположились несколько квартир с потолками от 5 до 6 метров с очень высокими ценами (несколько десятков миллионов), расположенные недалеко от центра города (расстояние до центра города менее 10 км), скорее всего, в элитных районах. Оставим эти дорогие квартиры для дальнейшего анализа. Остальные же строки представляются сомнительными, т.к. их немного, то избавление от этих строк существенно не отразится на конечном результате. Также не будем включать последнюю квартиру, расположенную в городе Бакситогорск и имеющую высоту потолков 5 м.

# %%
# создадим новую таблицу, в которой останутся только строки, удовлетворяющие условиям по корректной высоте потолков
data_good_ceiling = data.query('(ceiling_height >= 2.4 and ceiling_height < 5) or \
                               (ceiling_height > 5 and ceiling_height <= 6 and locality_name == "Санкт-Петербург")')

data_good_ceiling.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0  2019-03-07T00:00:00      3
# 4              2  10000000.0       100.0  2018-06-19T00:00:00      2
# 9             18   5400000.0        61.0  2017-02-26T00:00:00      3
# 10             5   5050000.0        39.6  2017-11-16T00:00:00      1
# 13            20   3550000.0        42.8  2017-07-01T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70          16.0         51.0      8         False   False
# 4             3.03          14.0         32.0     13         False   False
# 9             2.50           9.0         43.6      7         False   False
# 10            2.67          12.0         20.3      3         False   False
# 13            2.56           5.0         27.0      5         False   False
#
#     open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Снова выведем основные статистические данные для новой таблицы **data_good_ceiling**.

# %%
# выводим основные статистические характеристики столбца ceiling_height
data_good_ceiling['ceiling_height'].describe()
# Out:
# count    14473.000000
# mean         2.727315
# std          0.277276
# min          2.400000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видим, что теперь у нас еще уменьшилось среднее квадратичное отклонение, теперь оно **0.28**, медиана также осталась **2.65 метров**. Новая таблица поможет нам корректно заполнить пропуски в столбце **ceiling_height** и уже затем отсеять лишние значения и получить итоговую таблицу. Посмотрим, сколько пропусков в этом столбце.

# %%
# выводим сумму пропусков в столбце ceiling_height
data['ceiling_height'].isna().sum()
# Out:
# 9195

# %% [markdown]
# Для того, чтобы корректно заполнить пропуски выделим 4 категории квартир. Первая - это квартиры в пределах центра (возьмем расстояние до центра **5 км**), большинство из них будут квартиры старого фонда с высокими потолками, вторая категория - квартиры в пределах **10 км** (т.е. относительно недалеко от центра), третья категория - расстояние от центра **более 10 км** и четвертая категория - это квартиры в ЛО, для которых **не указано расстояние до центра** СПб.

# %% [markdown]
# Заполним пропуски в строках для квартир первой категории (находящиеся в центре).

# %%
# выбираем столбец ceiling_height только для тех строк, у которых значение city_centers_nearest меньше или равно 5000,
# но в то же время не равно нулю

data.loc[(data['city_centers_nearest'] <= 5000)&(data['city_centers_nearest'] != 0), 'ceiling_height'] = \
data['ceiling_height'].fillna(
    data_good_ceiling.loc[(data['city_centers_nearest'] <= 5000)&(data['city_centers_nearest'] != 0), 
                          'ceiling_height'].median()
)

# заполняем пропуски медианным значением из очищенной от аномальных значений таблицы data_good_ceiling
# для значений столбца ceiling_height для строк с тем же условием (<=5000 и != 0)

# %% [markdown]
# Теперь заполним пропуски в строках для второй категории квартир (расстояние до центра до 10 км).

# %%
# выбираем столбец ceiling_height только для тех строк, у которых значение city_centers_nearest больше 5000
# но меньше или равно 10000

data.loc[(data['city_centers_nearest'] > 5000)&(data['city_centers_nearest'] <= 10000), 'ceiling_height'] = \
data['ceiling_height'].fillna(
    data_good_ceiling.loc[(data['city_centers_nearest'] > 5000)&(data['city_centers_nearest'] <= 10000), 
                          'ceiling_height'].median()
)

# заполняем пропуски медианным значением из очищенной от аномальных значений таблицы data_good_ceiling
# для значений столбца ceiling_height для строк с тем же условием (<5000 и >= 10000)

# %% [markdown]
# Заполним пропуски в строках для третьей категории квартир (расстояние до центра более 10 км).

# %%
# выбираем столбец ceiling_height только для тех строк, у которых значение city_centers_nearest больше 10000

data.loc[data['city_centers_nearest'] > 10000, 'ceiling_height'] = \
data['ceiling_height'].fillna(
    data_good_ceiling.loc[data['city_centers_nearest'] > 10000, 'ceiling_height'].median()
)

# заполняем пропуски медианным значением из очищенной от аномальных значений таблицы data_good_ceiling
# для значений столбца ceiling_height для строк с тем же условием (>10000)

# %% [markdown]
# У нас остались пропуски в высоте потолков только для населенных пунктов в ЛО.

# %%
# заполняем оставшиеся пропуски медианным значением из очищенной от аномальных значений таблицы data_good_ceiling
data['ceiling_height'] = data['ceiling_height'].fillna(
    data_good_ceiling.loc[data['city_centers_nearest'] == 0, 'ceiling_height'].median()
)

# %% [markdown]
# Теперь избавимся от строк с аномальными высотами потолков для таблицы с заполненными пропусками по аналогии с **data_good_ceiling**.

# %%
# создадим новую таблицу, в которой останутся только строки, удовлетворяющие условиям по корректной высоте потолков:
good_data = data.copy().query('(ceiling_height >= 2.4 and ceiling_height < 5) or \
                               (ceiling_height > 5 and ceiling_height <= 6 and locality_name == "Санкт-Петербург")')

# %% [markdown]
# Выведем основные статистические характеристики столбца **ceiling_height** для очищенных от аномальных значений и с заполненными пропусками.

# %%
# выводим основные статистические характеристики столбца ceiling_height
good_data['ceiling_height'].describe()
# Out:
# count    23668.000000
# mean         2.701505
# std          0.236060
# min          2.400000
# 25%          2.600000
# 50%          2.600000
# 75%          2.770000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В итоге мы сохранили большинство строк, у нас осталось **23668** вместо 23699. Среднеквадратичное отклонение небольшое - **0.24**, медианное значение - **2.6 метров**, минимальное - **2.4 метра**, а максимальное - **6 метров**. Уже больше похоже на правду.

# %% [markdown]
# Теперь разберемся со столбцами **living_area** и **kitchen_area**. Столбец **living_area** имеет 1903 пропуска, столбец **kitchen_area** - 2278 пропусков. Но для начала посмотрим на распределение значений в столбце **total_area**.

# %%
# строим точечную диаграмму по значениям общей площади объектов недвижимости
good_data.plot(y='total_area', style='o', figsize=(10,8), legend=False)

# задаем название графика
plt.title('Распределение значений общей площади')

# задаем подпись оси Y
plt.ylabel('Общая площадь');

# %% [markdown]
# Видим, что большинство значений находится в диапазоне от **12** до **200** квадратных метров. Но также есть и квартиры с площадями от **200** и до **620** квадратных метров, а также одна квартира площадью **900 кв.м**. Выведем основные статистические данные этих строк.

# %%
# выводим основные статистические характеристики столбца total_area
good_data.query('total_area >= 200').describe().T
# Out:
#                       count          mean           std        min  \
# total_images          231.0  1.241126e+01  6.584544e+00        0.0
# last_price            231.0  5.926517e+07  7.373538e+07  7900000.0
# total_area            231.0  2.831445e+02  9.564909e+01      200.0
# rooms                 231.0  5.761905e+00  2.216445e+00        0.0
# ceiling_height        231.0  3.233463e+00  5.147310e-01        2.5
# floors_total          230.0  6.421739e+00  3.724164e+00        2.0
# living_area           202.0  1.643188e+02  5.654560e+01       55.0
# floor                 231.0  4.861472e+00  3.668649e+00        1.0
# kitchen_area          201.0  3.010771e+01  1.703108e+01       10.0
# balcony               231.0  3.809524e-01  8.609302e-01        0.0
# airports_nearest      231.0  2.630333e+04  8.013519e+03        0.0
# city_centers_nearest  231.0  7.125268e+03  6.695202e+03        0.0
# parks_around_3000     231.0  1.225108e+00  1.115687e+00        0.0
# ...

# %% [markdown]
# Видим, что цена для квартир с такой большой площадью тоже достаточно большая. Максимальная цена - **763 миллиона рублей**, медианная цена - **35 миллионов рублей**. Медианное количество комнат - **5**, а максимальное - **19!** что также достаточно много. Построим boxplot для столбца **total_area**.

# %%
# выводим boxplot для столбца total_area:
good_data.boxplot('total_area', figsize=(8,6))

# задаем название графика
plt.title('Боксплот для значений общей площади')

# задаем подпись оси Y
plt.ylabel('Общая площадь')

# отображаем получившийся график
plt.show()

# выводим boxplot для столбца total_area с ограничем по оси y
good_data.boxplot('total_area', figsize=(8,6))

# задаем подпись оси Y
plt.ylabel('Общая площадь')

# задаем ограничение оси Y
plt.ylim(100,125)

# отображаем получившийся график
plt.show()

# %% [markdown]
# Видим, что большое количество значений находится за пределами "усов", предел нормальных значений - **115 кв.м**. Посмотрим сколько квартир имеют площадь больше **115 кв.м**.

# %%
# выбираем строки, в которых значение столбца total_area более 115 кв.м.
good_data.query('total_area > 115')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 19               16  14200000.0      121.00  2019-01-09T00:00:00      3
# 35                6  15500000.0      149.00  2017-06-26T00:00:00      5
# 42               13  22000000.0      161.80  2015-07-08T00:00:00      4
# 51                7  45000000.0      161.00  2017-10-17T00:00:00      3
# ...             ...         ...         ...                  ...    ...
# 23574            14  64990000.0      139.00  2015-11-24T00:00:00      3
# 23590             0  21187872.0      123.30  2017-04-25T00:00:00      3
# 23600             8   8700000.0      132.00  2018-11-13T00:00:00      3
# 23684            20  21400000.0      145.00  2018-11-02T00:00:00      4
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Получили **1217 строк** - это квартиры с достаточно большой стоимостью, проверим какую долю занимают эти строки в общем датафрейме.

# %%
# делим количество отфильтрованных строк на кол-во строк в изначальном датафрейме
good_data[good_data['total_area'] > 115].shape[0]/data.shape[0]
# Out:
# 0.05135237773745727

# %% [markdown]
# Видим, что квартиры, площадью **более 120 кв.м.**, составляют **5%** от общего датафрейма. Это достаточно много, если учесть, что в других столбцах так же могут быть аномальные значения, которые придется удалять. Установим лимит в **140 кв.м**.

# %%
# делим количество отфильтрованных строк на кол-во строк в изначальном датафрейме
good_data[good_data['total_area'] > 140].shape[0]/data.shape[0]
# Out:
# 0.02932613190429976

# %% [markdown]
# Получили около **3%**. Удалим строки с квартирами площадью **менее 140 кв.м**.

# %%
# оставляем в таблице квартиры площадью до 140 кв.м.
good_data = good_data.query('total_area < 140')

# %% [markdown]
# Рассмотрим основные статистические характеристики получившегося столбца.

# %%
# выводим основные статистические характеристики столбца total_area
good_data['total_area'].describe()
# Out:
# count    22963.000000
# mean        56.018878
# std         21.949617
# min         12.000000
# 25%         40.000000
# 50%         51.000000
# 75%         67.180000
# max        139.800000
# Name: total_area, dtype: float64

# %% [markdown]
# Медианное значение - **51 кв. м.**, стандартное отклонение около **22 метров**. Максимальное значение - **139.8 кв.м**.
# Минимальное значение площади - **12 кв.м**. Это достаточно мало. Выведем строки со значением площади до 20 кв.м.

# %%
# выводим строки, в которых значение столбца total_area < 20
good_data.query('total_area < 20')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 716               5   1500000.0       17.00  2017-06-07T00:00:00      0
# 4542             12   3300000.0       18.00  2018-11-07T00:00:00      1
# 5855              3    945750.0       19.50  2017-09-18T00:00:00      0
# 6084              6    770000.0       18.00  2017-10-16T00:00:00      1
# 8454              7   2250000.0       19.00  2019-03-12T00:00:00      0
# 8729              9   2200000.0       18.40  2018-08-20T00:00:00      1
# 8755              1   1350000.0       18.80  2017-11-22T00:00:00      0
# 8886             10   2450000.0       15.50  2018-08-22T00:00:00      0
# 9157              0   3400000.0       17.60  2018-03-18T00:00:00      1
# 9412              5   2100000.0       16.00  2017-12-10T00:00:00      0
# 9817              8   2190000.0       19.00  2018-10-12T00:00:00      0
# 10208             3   1900000.0       17.00  2018-08-14T00:00:00      1
# ...

# %% [markdown]
# Видим, что квартиры площадью до **20 кв.м.** - это однокомнатные квартиры, а также это студии (т.к. значение в столбце **studio** True) и одна квартира со свободной планировкой (True в столбце **open_plan**). Для студий нет значения **kitchen_area**, т.к. в студиях и комнатах нет отдельной кухни. Цена на эти квратиры не высокая, от 1 до 3 млн.рублей. Так же есть квартиры стоимостью до миллиона рублей, но находятся они не в Санкт-Петербурге. Данные выглядят реально, значит можно опираться на столбец **total_area** для заполнения пропусков в столбцах **kitchen_area** и **living_area**.

# %%
# создадим таблицу, в которой будут строки, для которых известна общая площадь и площадь кухни:
data_area = good_data.query('total_area.isna() == False and kitchen_area.isna() == False')

# %% [markdown]
# Вероятнее, всего, для квартир или домов с большой площадью, доля кухни в общей площади будет меньше, чем для квартир с небольшой площадью. Выделим несколько категорий квартир. Первой будет категория с квартирами типичной площади - **до 50 кв.м**. Вторая категория **более 50 кв.м.**.

# %%
# создадим таблицу и поместим в нее строки, для которых значение столбца total_area <= 50 кв.м.
data_area_first = data_area.query('total_area <= 50')

# найдем медиану отношения площади кухни к общей площади
first_median = (data_area_first['kitchen_area']/data_area_first['total_area']).median()

first_median
# Out:
# 0.21866666666666665

# %% [markdown]
# Получили значение около **0.22**. Проделаем то же самое для второй категории.

# %%
# создадим таблицу и поместим в нее строки, для которых значение столбца total_area > 50 кв.м.:
data_area_second = data_area.query('total_area > 50')

# найдем медиану отношения площади кухни к общей площади:
second_median = (data_area_second['kitchen_area']/data_area_second['total_area']).median()

second_median
# Out:
# 0.15040091848450057

# %% [markdown]
# Как мы и думали, отношение площади кухни к общей площади для двух категорий квартир получилось разным. Теперь нам нужно найти строки, в которых известна общая площадь и неизвестна площадь кухни (для всех трех категорий). Так же нам необходимо исключить из этого списка квартиры-студии и квартиры со свободной планировкой, т.к. будем считать, что для них нет отдельного метража кухни.

# %%
# выбираем столбец kitchen_area для строк, в которых количество комнат не нулевое,
# столбец studio имеет значение False
# столбец open_plan имеет значение False
# столбец total_area <= 50
# в столбце kitchen_area есть пропуск
good_data.loc[(good_data['total_area'] <= 50)& \
                      (good_data['rooms'] != 0)& \
                      (good_data['studio'] == False)& \
                      (good_data['open_plan'] == False)& \
                      (good_data['kitchen_area'].isna()), 'kitchen_area'] = \
                      round((good_data.loc[(good_data['total_area'] <= 50), 'total_area'])*first_median, 2)
                      # заполняем этот пропуск значением столбца total_area умноженным на медианный коэффициент для квартир первой группы

# выбираем столбец kitchen_area для строк, в которых количество комнат не нулевое,
# столбец studio имеет значение False
# столбец total_area > 50 кв.м.
# в столбце kitchen_area есть пропуск
good_data.loc[(good_data['total_area'] > 50)& \
              (good_data['rooms'] != 0)& \
              (good_data['studio'] == False)& \
              (good_data['kitchen_area'].isna()), 'kitchen_area'] = \
              round((good_data.loc[(good_data['total_area'] > 50), 'total_area'])*second_median, 2)
              # заполняем этот пропуск значением столбца total_area умноженным на медианный коэффициент для квартир второй группы

# %% [markdown]
# Теперь у нас остались пропуски в столбце **kitchen_area** только для квартир, у которых значение в столбце **rooms** нулевое и значение в столбце **studio** - True. Заполним оставшиеся пропуски нулями.

# %%
# заполняем пропущенные столбца kitchen_area значения нулями
good_data['kitchen_area'] = good_data['kitchen_area'].fillna(0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6972\3605527006.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_data['kitchen_area'] = good_data['kitchen_area'].fillna(0)

# %% [markdown]
# Проверим, что в столбце **kitchen_area** не осталось пропусков.

# %%
# находим сумму пропущенных значениний в столбце kitchen_area
good_data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропусков в столбце **kitchen_area** не осталось. Посмотрим в каких столбцах еще есть пропуски.

# %%
# проверяем в каких столбцах еще остались пропуски
good_data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total              84
# living_area             1819
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name             47
# airports_nearest           0
# city_centers_nearest       0
# parks_around_3000          0
# parks_nearest              0
# ponds_around_3000          0
# ponds_nearest              0
# days_exposition         2991
# dtype: int64

# %% [markdown]
# У нас остались пропуски в столбце **living_area**. Заполним их по аналогии с тем, как мы заполняли пропуски в **kitchen_area**.

# %%
# создадим таблицу, в которой будут строки, для которых известна общая площадь и жилая площадь
data_living_area = good_data.query('total_area.isna() == False and living_area.isna() == False')

data_living_area.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
# 5            10   2890000.0        30.4  2018-09-10T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.60          11.0         18.6      1         False   False
# 2            2.60           5.0         34.3      4         False   False
# 4            3.03          14.0         32.0     13         False   False
# 5            2.60          12.0         14.4      5         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Разделим все квартиры также на три категории. Первой будет категория с квартирами типичной площади - **до 50 кв.м**. Вторая категория **более 50**. Найдем медиану отношений жилой площади к общей площади для всех групп.

# %%
# создадим таблицу со строками, в которых значение столбца total_area <= 50 кв.м.
data_living_first = data_living_area.query('total_area <= 50')

# найдем медиану отношения жилой площади к общей площади
living_median_first = (data_area_first['living_area']/data_area_first['total_area']).median()

living_median_first
# Out:
# 0.5214199570027791

# %%
# создадим таблицу со строками, в которых значение столбца total_area > 50 кв.м.
data_living_second = data_living_area.query('total_area > 50')

# найдем медиану отношения жилой площади к общей площади
living_median_second = (data_area_second['living_area']/data_area_second['total_area']).median()

living_median_second
# Out:
# 0.592734225621415

# %% [markdown]
# Медианы для трех групп не так уж сильно отличаются друг от друга. Теперь заполним пустые значения в столбце **living_area** с учетом найденного коэффициента.

# %%
# выбираем столбец living_area для строк в которых,
# столбец total_area <= 50 кв.м.
# в столбце living_area есть пропуск

good_data.loc[(good_data['total_area'] <= 50)& \
              (good_data['living_area'].isna()), 'living_area'] = \
              round((good_data.loc[(good_data['total_area'] <= 50), 'total_area'])*living_median_first, 2) 
              # заполняем этот пропуск значением столбца total_area 
              # умноженным на медианный коэффициент для квартир первой группы

# выбираем столбец living_area для строк, в которых 
# столбец total_area > 50 кв.м
# в столбце living_area есть пропуск

good_data.loc[(good_data['total_area'] > 50)& \
              (good_data['living_area'].isna()), 'living_area'] = \
              round((good_data.loc[(good_data['total_area'] > 50), 'total_area'])*living_median_second, 2)
              # заполняем этот пропуск значением столбца total_area
              # умноженным на медианный коэффициент для квартир второй группы

# %% [markdown]
# Убедимся, что в столбце **living_area** не осталось пропусков.

# %%
# суммируем пропуски в столбце living_area
good_data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# В итоге у нас остались 3177 пропусков в столбце **days_exposition**, который показывает сколько дней было размещено объявление (от публикации до снятия). Пропуски в этом столбце могут означать, что объявление еще не было закрыто, т.е. квартира еще не продана. Заполним пропуски в этом столбце нулями для того, чтобы изменить тип данных на целочисленный. Также остались пропуски в столбцах **locality_name** - 49 строк и в **floors_total** - 86 строк. **Locality_name** не будем, т.к. такое маленькое количество строк не повлияет на итоговую статистику. А вот пропуски в столбце **floors_total** заполним нулями для того, чтобы перевести тип данных в целочисленный.

# %%
#заполняем пропуски в столбцах floors_total и days_exposition нулями и переводим тип данных в int
good_data['floors_total'] = good_data['floors_total'].fillna(0).astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6972\2979616342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_data['floors_total'] = good_data['floors_total'].fillna(0).astype('int64')

# %% [markdown]
# Выведем основные статистические характеристики для подготовленной таблицы.

# %%
# выводим основные статистические характеристики таблицы good_data
good_data.describe().T
# Out:
#                         count          mean           std      min        25%  \
# total_images          22963.0  9.813787e+00  5.634058e+00      0.0        6.0
# last_price            22963.0  5.597627e+06  4.185676e+06  12190.0  3400000.0
# total_area            22963.0  5.601888e+01  2.194962e+01     12.0       40.0
# rooms                 22963.0  1.988808e+00  9.369117e-01      0.0        1.0
# ceiling_height        22963.0  2.688706e+00  2.154757e-01      2.4        2.6
# floors_total          22963.0  1.071620e+01  6.641994e+00      0.0        5.0
# living_area           22963.0  3.202741e+01  1.481847e+01      2.0       18.6
# floor                 22963.0  5.905457e+00  4.904176e+00      1.0        2.0
# kitchen_area          22963.0  9.971937e+00  4.704806e+00      0.0        7.0
# balcony               22963.0  5.947394e-01  9.561104e-01      0.0        0.0
# airports_nearest      22963.0  2.341505e+04  1.682556e+04      0.0    11637.0
# ...

# %% [markdown]
# Видим, что есть аномальное значение в столбце **last_price** - 12190 рублей, а также достаточно большое максимальное значение - **82000000 млн.руб.** Построим boxplot для этого столбца.

# %%
# строим боксплот по столбцу last_price
good_data.boxplot('last_price', figsize=(8,6))

# задаем название графика
plt.title('Боксплот для значений стоимости объекта недвижимости')

# задаем подпись оси Y
plt.ylabel('Стоимость')

# отображаем получившийся график
plt.show()

# строим боксплот по столбцу last_price
good_data.boxplot('last_price', figsize=(8,6))

# задаем ограничение оси Y
plt.ylim(1e+7, 1.2e+7)

# задаем подпись оси Y
plt.ylabel('Стоимость')

# отображаем получившийся график
plt.show();

# %% [markdown]
# У нас есть достаточно много выбросов, установим верхний предел в **11.1 млн.рублей** и посмотрим какую часть занимают строки с большим значением относительно начального датафрема.

# %%
# находим кол-во строк, в которых значение столбца last_price > 1.11e+7
# и делим на число строк в изначальном датасете
good_data.loc[good_data['last_price'] > 1.11e+7].shape[0]/data.shape[0]
# Out:
# 0.06730241782353685

# %% [markdown]
# Видим, что таких данных - **6.7%** от изначального датафрейма. Если учесть, что до этого мы уже удаляли часть данных, то установим предел 14 млн.рублей для того, чтобы у нас осталось больше данных.

# %%
# находим кол-во строк, в которых значение столбца last_price > 1.4e+7
# и делим на число строк в изначальном датасете
good_data.loc[good_data['last_price'] > 1.4e+7].shape[0]/data.shape[0]
# Out:
# 0.033292543989197856

# %% [markdown]
# Получили **3.3%** данных, вполне приемлемо. Удалим эти строки из датафрейма.

# %%
# оставляем в датасете только строки, в которых значение столбца last_price > 1.4e+7
good_data = good_data.loc[good_data['last_price'] < 1.4e+7]

# %% [markdown]
# Теперь выведем строку с минимальной ценой - **12190 рублей**.

# %%
# выбираем строку, в которой значения столбца last_price равно 12190
good_data.query('last_price == 12190')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7     12190.0       109.0  2019-03-20T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 8793            2.75            25         32.0     25         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 8793      False          40.5        0  Санкт-Петербург             36421
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 8793                  9176                  1              0
#
#       ponds_around_3000  ponds_nearest  days_exposition
# 8793                  0              0              8.0

# %% [markdown]
# Возможно, здесь произошла опечатка и реальная цена должна быть 12 млн. 190 тыс. рублей. Но наверняка мы этого не знаем, поэтому просто удалим эту строку из нашего датафрейма.

# %%
# удаляем строку с индексом 8793
good_data = good_data.drop(index=8793) 

# выводим основные статистические характеристики
good_data.describe().T
# Out:
#                         count          mean           std       min  \
# total_images          22142.0  9.729925e+00  5.571162e+00       0.0
# last_price            22142.0  5.039490e+06  2.520697e+06  430000.0
# total_area            22142.0  5.419689e+01  1.978811e+01      12.0
# rooms                 22142.0  1.954250e+00  9.223170e-01       0.0
# ceiling_height        22142.0  2.677416e+00  2.024735e-01       2.4
# floors_total          22142.0  1.074785e+01  6.663715e+00       0.0
# living_area           22142.0  3.105142e+01  1.380233e+01       2.0
# floor                 22142.0  5.904254e+00  4.915725e+00       1.0
# kitchen_area          22142.0  9.627297e+00  4.050212e+00       0.0
# balcony               22142.0  5.941649e-01  9.485468e-01       0.0
# airports_nearest      22142.0  2.323584e+04  1.701892e+04       0.0
# city_centers_nearest  22142.0  1.178548e+04  9.762437e+03       0.0
# parks_around_3000     22142.0  4.264294e-01  7.107113e-01       0.0
# ...

# %% [markdown]
# Видим, что теперь у нас минимальная цена - **430 тысяч рублей**. Для небольшой квартиры в деревне, скорее всего, имеет место быть. Изменим тип этого столбца на целочисленный, т.к. точность до рублей не нужна.

# %%
# перезаписываем значения столбца на значения с измененным типом данных
good_data['last_price'] = good_data['last_price'].astype('int64')

# %% [markdown]
# Также видим аномальное значение для общего количества этажей в доме - **60**. Построим boxplot для этого столбца.

# %%
# строим боксплот для столбца floors_total
good_data.boxplot('floors_total', figsize=(8,6))

# задаем название графика
plt.title('Боксплот для значений количества этажей в доме')

# задаем подпись оси Y
plt.ylabel('Количество этажей')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что у нас есть несколько выбросов, это дома с количеством этажей **от 32 до 36**, и два значения **больше 50 этажей**. Дома этажностью до 40 этажей еще представляются возможными, а вот более - уже маловероятно. Выведем строки с количеством этажей **более 40** и удалим их по индексу строк.

# %%
# выбираем строки, в которых значения столбца floors_total > 40
good_data.query('floors_total > 40')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2253             12     3800000        45.5  2018-06-28T00:00:00      2
# 16731             9     3978000        40.0  2018-09-24T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 2253             2.88            60         27.4      4         False   False
# 16731            2.65            52         10.5     18         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 2253       False           7.4        0        Кронштадт             67763
# 16731      False          14.0        0  Санкт-Петербург             20728
#
#        city_centers_nearest  parks_around_3000  parks_nearest  \
# 2253                  49488                  2              0
# 16731                 12978                  1              0
#
#        ponds_around_3000  ponds_nearest  days_exposition
# ...

# %%
# удаляем из таблицы строки с индексами 2253 и 16731:
good_data = good_data.drop(index=[2253,16731])

# %% [markdown]
# Теперь рассмотрим столбец **rooms**, максимальное значение - **7 комнат**. Построим boxplot для этого столбца.

# %%
# строим боксплот для столбца rooms
good_data.boxplot('rooms', figsize=(8,6))

# задаем название графика
plt.title('Боксплот для значений количества комнат')

# задаем подпись оси Y
plt.ylabel('Количество комнат')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что у нас есть выбивающееся значение - **7 комнат**. Выведем эти строки.

# %%
# выбираем строки, в которых значения столбца rooms равно 7
good_data.query('rooms == 7')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14603            12    13490000       100.6  2018-07-31T00:00:00      7
# 17991            19    12000000       125.0  2017-02-09T00:00:00      7
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 14603             3.1             4        59.63      2          True   False
# 17991             3.3             6        82.00      5         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 14603      False         15.13        0  Санкт-Петербург             24309
# 17991      False         24.00        0  Санкт-Петербург             24697
#
#        city_centers_nearest  parks_around_3000  parks_nearest  \
# 14603                  3876                  3              0
# 17991                  5265                  1              0
#
#        ponds_around_3000  ponds_nearest  days_exposition
# ...

# %% [markdown]
# Получили **2 строки**, это очень мало, поэтому мы можем удалить их из нашего датафрейма.

# %%
# оставляем в таблице строки для которых количество комнат не равно 7
good_data = good_data.loc[good_data['rooms']!=7]

# %% [markdown]
# Теперь нам нужно проверить, что мы удалили не слишком много данных из изначального датафрейма. Разделим количество строк в текущем датафрейме на количество строк в изначальных данных.

# %%
# делим кол-во строк в "очищенном" датафрейме на число строк в изначальном датафрейме
1 - (good_data.shape[0]/data.shape[0])
# Out:
# 0.06586775813325452

# %% [markdown]
# Получили около **6.59%**. Такое значение допустимо. Выведем еще раз общую информацию о таблице.

# %%
good_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22138 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22138 non-null  int64
#  1   last_price            22138 non-null  int64
#  2   total_area            22138 non-null  float64
#  3   first_day_exposition  22138 non-null  object
#  4   rooms                 22138 non-null  int64
#  5   ceiling_height        22138 non-null  float64
#  6   floors_total          22138 non-null  int64
#  7   living_area           22138 non-null  float64
#  8   floor                 22138 non-null  int64
#  9   is_apartment          22138 non-null  bool
#  10  studio                22138 non-null  bool
#  11  open_plan             22138 non-null  bool
#  12  kitchen_area          22138 non-null  float64
#  13  balcony               22138 non-null  int64
#  14  locality_name         22093 non-null  object
# ...

# %% [markdown]
# <div style = "border:solid green 2px; padding:20px">
# Итак, мы провели предобработку данных, избавились, по возможности, от пропусков и аномальных значений. Получили итоговую очищенную таблицу - <b>good_data</b>.
# </div>

# %% [markdown]
# <a id='chapter_8'></a>Теперь добавим в таблицу новые столбцы. В столбец **good_data** добавим цену одного квадратного метра. Для этого разделим значения из столбца **last_price** на значения столбца **total_area**.

# %%
# создаем новый столбец meter_price,
# используем целочисленное деление для того, чтобы получить числа без знаков после запятой
good_data['meter_price'] = (good_data['last_price']/good_data['total_area']).astype('int64')

# %% [markdown]
# <a id='chapter_9'></a>Создадим столбец с днем недели публикации объявления (0 — понедельник, 1 — вторник и так далее). У нас есть столбец с датой размещения объявления **first_day_exposition** в стандартном формате: год-месяц-деньTвремя. Время для всех объявлений указано 00:00:00, но для анализа нам оно не потребуется. Но этот столбец имеет формат **object**, переведем его в формат **datetime**

# %%
# используем метод to_datetime для перевода значений столбца first_day_exposition в формат datetime
good_data['first_day_exposition'] = pd.to_datetime(good_data['first_day_exposition'], 
                                                   format='%Y-%m-%dT%H:%M:%S')

# %%
# создаем новый столбец num_day_exposition
# используем атрибут dt с методом weekday для вывода номера дня
good_data['num_day_exposition'] = good_data['first_day_exposition'].dt.weekday

# %% [markdown]
# <a id='chapter_10'></a>Теперь создадим еще два столбца - месяц публикации объявления и год публикации объявления.

# %%
# создаем новый столбец num_month_exposition
# используем атрибут dt с методом month для вывода номера месяца
good_data['num_month_exposition'] = good_data['first_day_exposition'].dt.month

# %%
# создаем новый столбец year_exposition
# используем атрибут dt с методом year для вывода года
good_data['year_exposition'] = good_data['first_day_exposition'].dt.year

# %% [markdown]
# <a id='chapter_11'></a>Создадим еще один столбец с типом этажа квартиры ("первый", "последний" или "другой")

# %%
# создаем новый столбец type_of_floor со значением первый для строк, в которых
# значение столбца floor равно 1 и не равно 0 (это пропуски в столбце floor)
good_data.loc[(good_data['floor'] == 1)&(good_data['floors_total'] != 0), 'type_of_floor'] = 'первый'

# создаем новый столбец type_of_floor со значением последний для строк, в которых
# значение столбца floor равно значению floors_total и не равно 0 (это пропуски в столбце floor)
good_data.loc[(good_data['floor'] == good_data['floors_total'])& \
              (good_data['floors_total'] != 0), 'type_of_floor'] = 'последний'

# создаем новый столбец type_of_floor со значением другой для строк, в которых
# значение столбца floor не равно значению floors_total и не равно 0 и 1
good_data.loc[(good_data['floor'] != good_data['floors_total'])& \
              (good_data['floor'] != 1)&(good_data['floors_total'] != 0), 'type_of_floor'] = 'другой'

# %% [markdown]
# Стоит отметить, что в новом столбце **type_of_floor** будут пропуски для строк, у которых нет значения **floors_total**.

# %% [markdown]
# <a id='chapter_12'></a>Еще одним столбцом станет расстояние до центра города в километрах - **city_centers_kms**.

# %%
# создаем новый столбец разделив значения столбца city_centers_nearest на 1000 
# и переведем в целочисленный тип
good_data['city_centers_kms'] = round(good_data['city_centers_nearest']/1000).astype('int64')

# %% [markdown]
# Выведем получившуюся таблицу.

# %%
# выводим первые пять строк получившейся таблицы
good_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 4             2    10000000       100.0           2018-06-19      2
# 5            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.60            11         18.6      1         False   False
# 2            2.60             5         34.3      4         False   False
# 4            3.03            14         32.0     13         False   False
# 5            2.60            12         14.4      5         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div style = "border:solid green 2px; padding:20px"> Для удобства дальнейшего анализа добавили 6 новых столбцов в таблицу <b>good_data</b>.
# </div>

# %% [markdown]
# ### Часть 3. Исследовательский анализ данных

# %% [markdown]
# <a id='chapter_13'></a>Начнем рассматривать параметры объектов по отдельности. Сначала рассмотрим основные статистические характеристики столбца с общей площадью.

# %%
# выводим основные статистические характеристики столбца total_area
good_data['total_area'].describe()
# Out:
# count    22138.000000
# mean        54.192630
# std         19.781397
# min         12.000000
# 25%         39.100000
# 50%         50.000000
# 75%         65.000000
# max        139.800000
# Name: total_area, dtype: float64

# %% [markdown]
# Медианное значение для данного столбца - **50 кв. м.**, стандартное отклонение у нас достаточно большое (**19.8 кв.м.**), т.к. у нас есть квартиры с маленькой площадью и с достаточно большой. Третий квартиль равен **65 кв.м.**, а максимальное значение - **139.8 кв.м**. Пропусков в данном столбце нет. Построим гистограмму для этого столбца.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# выводим гистограмму для столбца total_area
plt.hist(good_data['total_area'], 
         bins=20, 
         color='#222261')

# выводим медиану столбца total_area на график
plt.axvline(good_data['total_area'].median(), 
            color='r', 
            linestyle='--', 
            label='медиана')

# выводим легенду
plt.legend()

# выводим название
plt.title('Распределение числа квартир в зависимости от общей площади') 

# задаем подпись оси x
plt.xlabel('Общая площадь квартиры, м2')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что основная масса значений находится в пределах **от 30 до 50 кв.м**. Значений от **80 кв.м.** в несколько раз меньше.

# %% [markdown]
# <a id='chapter_14'></a>Теперь рассмотрим основные статистические характеристики столбца **kitchen_area**. Не забудем исключить нулевые значения, на которые мы заменили пропуски.

# %%
# выбираем строки, для которых значение столбца kitchen_area не равно 0
good_data.loc[good_data['kitchen_area']!=0, 'kitchen_area'].describe()
# Out:
# count    21929.000000
# mean         9.718049
# std          3.957275
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         64.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# В данном столбце имеются пропуски, которые были заменены на нули ранее (это строки с квартирами-студиями и квартирами со свободной планировкой), поэтому строки с пропусками в этом столбце были исключены. Минимальное значение - **1.3 кв.м.**. Первый квартиль - **7 кв.м.**, медиана - **9 кв.м**. Максимальная площадь кухни - **64 кв.м**. Это связано с тем, что у нас есть квартиры с большой площадью. Построим гистограмму для этого столбца.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# выводим гистограмму для столбца kitchen_area
plt.hist(good_data['kitchen_area'], bins=20)

# выводим медиану столбца total_area на график
plt.axvline(good_data.loc[good_data['kitchen_area']!=0, 'kitchen_area'].median(), 
            color='r', 
            linestyle='--', 
            label='медиана')

# выводим среднее значение столбца total_area на график
plt.axvline(good_data.loc[good_data['kitchen_area']!=0, 'kitchen_area'].mean(), 
            color='orange', 
            linestyle='-.', 
            label='среднее')

# выводим легенду
plt.legend()

# задаем название графика
plt.title('Распределение числа квартир в зависимости от площади кухни')

# задаем подпись оси x
plt.xlabel('Площадь кухни, м2')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что пропусков в этом столбце было относительно немного. Большинство значений площади кухни приходится на диапазон **от 5 до 10 кв.м.** Намного меньше значений для кухонь площадью от 10 и более кв.м. Кухонь площадью от **20 метров** совсем минимальное количество.

# %% [markdown]
# <a id='chapter_15'></a>Теперь рассмотрим столбец **last_price**.

# %%
# выводим основные статистические характеристики столбца last_price
good_data['last_price'].describe()
# Out:
# count    2.213800e+04
# mean     5.038898e+06
# std      2.519827e+06
# min      4.300000e+05
# 25%      3.350000e+06
# 50%      4.500000e+06
# 75%      6.200000e+06
# max      1.399900e+07
# Name: last_price, dtype: float64

# %% [markdown]
# В этом столбце пропусков не было. Минимальное значение **430 тыс. рублей**. Медиана - **4.5 миллиона**. Стандартное отклонение достаточно большое, **2.5 млн.рублей**. Максимальное значение цены - **около 14 млн. рублей**. Построим гистограмму.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# выводим гистограмму для столбца last_price
plt.hist(good_data['last_price'], bins=20)

# выведем медиану
plt.axvline(good_data['last_price'].median(), 
            color='r', 
            linestyle='--', 
            label='медиана')

# задаем название графика
plt.title('Распределение числа квартир в зависимости от их стоимости')

# задаем подпись оси x
plt.xlabel('Цена на момент снятия с публикации')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# выводим легенду
plt.legend()

# отображаем получившийся график
plt.show();

# %% [markdown]
# Большинство значений находится в диапазоне от **3,5 до 4,5 млн.руб.** чуть меньше значений в диапазоне **от 3 до 3.5 млн.руб.**, и **от 4.5 до 5 млн.руб**. В несколько раз меньше квартир стоимостью **от 6 миллионов рублей и выше**.

# %% [markdown]
# <a id='chapter_16'></a>Далее рассмотрим количество комнат **rooms**, это категориальная переменная. Рассмотрим ее основные статистические характеристики.

# %%
# выводим основные статистические характеристики столбца rooms
good_data['rooms'].describe()
# Out:
# count    22138.000000
# mean         1.953835
# std          0.921130
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Минимальное значение - **0 комнат**, но это не пропуски, а, скорее всего, квартиры-студии. Медианное значение - **2 комнаты**, максимальное количество - **6 комнат**. Удобнее всего будет рассмотреть количество комнат на столбчатом графике.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# выводим столбчатый график для уникальных значений столбца rooms
good_data['rooms'].value_counts().plot(kind='bar', 
                                       title='Распределение числа квартир в зависимости от количества комнат')

# задаем подпись оси x
plt.xlabel('Количество комнат в квартире')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Большинство квартир имеют **1-2 комнаты**, чуть меньше квартир имеют **3 комнаты**. Намного меньше квартир имеют **4 и более** комнат. Так же в нашем датасете количество студий очень небольшое.

# %% [markdown]
# <a id='chapter_17'></a>Далее рассмотрим высоту потолков - **ceiling_height**. Выведем основные статистические характеристики столбца.

# %%
# выводим основные статистические характеристики столбца ceiling_height
good_data['ceiling_height'].describe()
# Out:
# count    22138.000000
# mean         2.677361
# std          0.202424
# min          2.400000
# 25%          2.600000
# 50%          2.600000
# 75%          2.750000
# max          5.800000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Пропусков в данном столбце нет. Минимальное значение - **2.4 метра**. Медианное значение - **2.6 метра**. Среднекватритичное отклонение небольшое - **20 сантиметров**. Максимальная высота потолка - **5.8 метров**. Посчитаем сколько всего у нас уникальных значений высоты потолков.

# %%
# выводим количество уникальных значений в столбце ceiling_height
good_data['ceiling_height'].nunique()
# Out:
# 142

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# строим гистограмму для высоты потолков
good_data['ceiling_height'].plot(kind='hist', 
                                 color='purple',
                                 title='Распределение числа квартир в зависимости от высоты потолков')

# выведем медиану
plt.axvline(good_data['ceiling_height'].median(),
            color='r', 
            linestyle='--',
            label='медиана')

# задаем подпись оси x
plt.xlabel('Высота потолка, м')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отражаем график
plt.show();

# %% [markdown]
# Подавляющее большинство квартир имеют высоту потолков от **2.4 метров** до **2.75 метров**, более чем в три раза меньше квартир с высотой потолков от **2.75 до 3.10** метров. Совсем минимальное количество квартир имеют потолки более **3.10 метра**.

# %% [markdown]
# <a id='chapter_18'></a>Теперь рассмотрим столбцы с этажом квартиры и с типом этажа, а также общее количество этажей в доме.

# %%
# выводим основные статистические характеристики столбца floor
good_data['floor'].describe()
# Out:
# count    22138.000000
# mean         5.904011
# std          4.915407
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Пропусков в данном столбце не было. Медиана - **4 этаж**. Стандартное отклонение достаточно большое - около 5 этажей, это связано с тем, что у нас есть достаточно высокие дома - выше 30 этажей (максимум - **33 этажа**). 75% всех данных лежат в пределах **8 этажей**. Построим столбчатый график для каждого уникального значения в столбце **floor**.

# %%
# задаем размер графика
plt.figure(figsize=(10,10))

# строим столбчатый график размером 10х10 по уникальным значениям столбца floor
good_data['floor'].value_counts().plot(kind='bar', 
                                       title='Распределение числа квартир в зависимости от количества этажей')

# задаем подпись оси x
plt.xlabel('Количество этажей в доме')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отражаем график
plt.show();

# %% [markdown]
# Большинство квартир находятся на **1-5 этажах**, более чем в 2 раза меньше квартир расположены на **6-9 этажах.** Еще чуть меньше квартир на **10-12 этажах**. Совсем минимальное количество квартир находятся на **17 этаже** и выше.

# %% [markdown]
# Столбец тип этажа **type_of_floor** это категориальная переменная. Построим для нее столбчатый график.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# строим столбчатый график для каждого уникального значения столбца type_of_floor
good_data['type_of_floor'].value_counts().plot(kind='bar', 
                                               title='Распределение кол-ва объектов недвижимости по типу этажа', 
                                               color=['orange', 'blue', 'magenta']);

# задаем подпись оси x
plt.xlabel('Тип этажа')

# задаем угол поворота подписей оси x
plt.xticks(rotation=45)

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Преобладающее большинство квартир имеют **другой** тип этажа, т.е. не первый и не последний. Примерно одинаковое количество квартир имеют первый и последний этажи. Теперь рассмотрим общее количество этажей в доме.

# %%
# выводим основные статистические характеристики столбца floors_total
good_data['floors_total'].describe()
# Out:
# count    22138.000000
# mean        10.744286
# std          6.650081
# min          0.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         36.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# В этом столбце мы нулями заменяли пропуски в данных, поэтому минимальное значение - 0. Медиана - **9 этажей**, стандартное отклонение достаточно большое - **около 7 этажей**. Это объясняется тем, что у нас есть высокие дома - максимальное значение - **36 этажей**. Построим столбчатую диаграмму по уникальным значениям в столбце, т.к. она более удобна в этом случае, значения распределятся от большего к меньшему.

# %%
# строим столбчатый график для каждого уникального значения столбца floors_total
good_data['floors_total'].value_counts().plot(kind='bar', 
                                              title='Распределение числа квартир в зависимости от этажности дома', 
                                              color='gold', 
                                              figsize=(10,10))

# задаем подпись оси x
plt.xlabel('Количество этажей в доме')

# задаем подпись оси y
plt.ylabel('Количество квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# В нашем датафрейме преобладают **5-ти этажные** дома (таких домов почти 6 тысяч), затем идут **9-ти этажные** дома (их около 4 тысяч), совсем мало домов имеют **28 этажей и выше**.

# %% [markdown]
# <a id='chapter_19'></a>Теперь рассмотрим столбцы с расстоянием до центра города в метрах **city_centers_nearest**, расстояние до ближайшего аэропорта **airports_nearest**, расстояние до ближайшего парка **parks_nearest**.

# %%
# рассмотрим основные статистические характеристики столбца city_centers_nearest
good_data.loc[good_data['city_centers_nearest']!=0, 'city_centers_nearest'].describe()
# Out:
# count    17330.000000
# mean     15053.807675
# std       8512.435045
# min        208.000000
# 25%      10574.000000
# 50%      13717.000000
# 75%      17073.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# В данном столбце у нас много пропусков, поэтому мы исключили нулевые значения из статистического расчета. Медиана здесь - **13717 метрв**. Стандартное отклонение достаточно большое - **8512 метров**, т.к. есть очень удаленные от центра города квартиры - максимальное значение - около **65968 метров**. Минимальное - **208 метров**.

# %%
# рассмотрим основные статистические характеристики столбца airports_nearest
good_data.loc[good_data['airports_nearest'] != 0, 'airports_nearest'].describe()
# Out:
# count    17329.000000
# mean     29681.488141
# std      13363.843354
# min       6450.000000
# 25%      18487.000000
# 50%      27638.000000
# 75%      39347.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# В этом столбце у нас так же были пропуски, поэтому из расчета мы их исключили. Видим, что минимальное расстояние до аэропорта - **6450 метров**. Медиана - **27638 метров**. Стандартное отклонние достаточно большое, т.к. у нас имеются очень удаленные от аэропорта квартиры - максимальное значение - **84869 метров**.

# %%
# рассмотрим основные статистические характеристики столбца parks_nearest
good_data.loc[good_data['parks_nearest'] != 0, 'parks_nearest'].describe()
# Out:
# count       3.000000
# mean     3148.000000
# std        72.746134
# min      3064.000000
# 25%      3127.000000
# 50%      3190.000000
# 75%      3190.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Минимальное расстояние до парка - **3064 метра**, максимальное - **3190 метров**. Распределение значений в этом столбце достаточно однородное, стандратное отклонение - **72.7 метров**. Это объясняется тем, что расстояние до ближайших парков указывалось только в случае, если парк находится в пределах трех километров.

# %% [markdown]
# Построим гистограммы для **city_centers_nearest** и **airports_nearest**.

# %%
# выводим гистограмму столбца city_centers_nearest
good_data['city_centers_nearest'].plot(kind='hist',
                                       bins=20, 
                                       title='Распределение квартир по расстоянию до центра города',
                                       color='magenta', 
                                       figsize = (8,6))

# задаем подпись оси x
plt.xlabel('Расстояние до центра, м')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# отображаем получившийся график
plt.show()

# выберем предел, в который войдет большинство значений
good_data['city_centers_nearest'].plot(kind='hist', 
                                       bins=20, 
                                       title='Распределение квартир по расстоянию до центра города', 
                                       color='blue', 
                                       figsize = (8,6))

# ограничиваем ось x
plt.xlim(100, 20000)

# задаем подпись оси x
plt.xlabel('Расстояние до центра, м')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что для большинства квартир у нас нет расстояния до центра города, значит, это квартиры, расположенные за пределами СПб. Около 5.5 тысяч квартир имеют расстояние до центра города в пределах **2.5 км.**, а так же около 8 тысяч квартир имеют расстояние до центра **от 10 до 16.5 км**. Расстояние **более 17 км.** имеют в несколько раз меньшее количество квартир.

# %%
# выводим гистограмму столбца city_centers_nearest
good_data['airports_nearest'].plot(kind='hist',
                                   bins=20, 
                                   title='Распределение квартир по расстоянию до аэропорта', 
                                   color='green', 
                                   figsize = (8,6))

# задаем подпись оси x
plt.xlabel('Расстояние до аэропорта, м')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Для большинства квартир нет расстояния до аэропорта, значит, они находятся достаточно далеко. Небольшой пик имеется около **10000 метров**. Чуть меньше квартир имеют расстоние **от 10000 до 25000 метров**. Так же достаточно большое количество квартир имеет расстояние до аэропорта **от 20000 до 40000 метров**. А вот квартир с расстоянием **от 55000 метров** минимальное количество.

# %% [markdown]
# <a id='chapter_20'></a>Теперь рассмотрим столбцы с днем и месяцем публикации объявления. Построим для них столбчатые графики (т.к. это категориальные параметры).

# %%
# строим столбчатый график для дня публикации объявления
good_data['num_day_exposition'].value_counts().plot(kind='bar', 
                                                    title='Распределение количества квартир по дню публикации',
                                                    figsize = (8,6))

# задаем подпись оси x
plt.xlabel('День публикации')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Видим, что размещение объявлений распределено по будним дням недели почти равномерно. По выходным объявления публикуют намного реже.

# %%
# строим столбчатый график для месяца публикации объявления
good_data['num_month_exposition'].value_counts().plot(kind='bar', 
                                                      title='Распределение количества квартир по месяцу публикации', 
                                                      color='lightgreen',
                                                      figsize = (8,6));
# задаем подпись оси x
plt.xlabel('Месяц публикации')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# отображаем получившийся график
plt.show();

# %% [markdown]
# Больше всего объявлений публикуют в феврале, марте, апреле и ноябре. Чуть меньше в сентябре и октябре. Потом идут летние месяцы и декабрь, январь, май. Отсюда можно сделать вывод, что меньше всего публикуют объявлений в летние месяцы и в месяцы, когда есть длинные государственные праздники.

# %% [markdown]
# <a id='chapter_21'></a>Изучим, как быстро продавались квартиры (столбец **days_exposition**). Этот параметр показывает, сколько дней было размещено каждое объявление. Выведем основные статистические характеристики столбца и построим гистограмму.

# %%
# рассмотрим основные статистические характеристики столбца days_exposition
good_data['days_exposition'].describe()
# Out:
# count    19383.000000
# mean       174.838725
# std        213.568979
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        221.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Минимальный срок закрытия объявления - **1 день**, максимальный - **1580 дней**. Медианное время - **92 дня**, а вот среднее - почти **175 дней**. Это связано с тем, что у нас есть очень долгие продажи. Найдем границы нормальных значений с помощью boxplot.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# строим boxplot для столбца days_exposition
good_data.boxplot('days_exposition')

# задаем название графика
plt.title('Боксплот для количества дней размещения объявления')

# задаем подпись оси y
plt.ylabel('Кол-во дней размещения объявления')

# выводим получившийся график
plt.show();

# %% [markdown]
# Видим, что выбросы у нас начинаются приблизительно от **500 дней**. Можем считать такие продажи необычайно долгими. Построим гистограмму для этого столбца.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# строим гистограмму по количеству дней размещения объявлений 
good_data['days_exposition'].plot(kind='hist', 
                                  bins=100)

# строим медиану 
plt.axvline(good_data['days_exposition'].median(), 
            linestyle = '--', 
            color = 'r')

# задаем названия графика
plt.title('Гистограмма количества дней размещения объявления')

# задаем подпись оси x
plt.xlabel('Количество дней размещения объявления')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# выводим получившийся график
plt.show();

# %% [markdown]
# Видим, что значений с продажей более **500 дней** не так уж и много. Скорее всего долго продаются очень дорогие и большие квартиры, т.к. спрос на них явно ниже, чем на обычное жилье. Большинство квартир продаются **менее 100 дней**. Отбросим все значения со временем продажи более 500 дней и найдем среднее и медиану для таких квартир.

# %%
# выводим основные статистические данные для строк со сроком размещения объявления менее 100 дней
good_data.loc[good_data['days_exposition'] < 500, 'days_exposition'].describe()
# Out:
# count    17838.000000
# mean       124.767351
# std        117.938759
# min          1.000000
# 25%         40.000000
# 50%         81.000000
# 75%        178.000000
# max        499.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Для среза данных медианное значение получилось **81 день**, среднее **125 дней**, первый квартиль - **40 дней**.

# %% [markdown]
# Теперь посмотрим на быстрые продажи, выведем строки, у которых время продажи менее 30 дней.

# %%
# выбираем строки для которых время размещения объявлений менее 30 дней
good_data.query('days_exposition < 30')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11                9     3300000        44.0           2018-08-27      2
# 15               16     4650000        39.0           2017-11-18      1
# 34                3     3290000        33.0           2018-02-04      1
# 39               15     5200000        54.4           2018-11-29      2
# 53                7     4300000        39.1           2017-11-10      1
# ...             ...         ...         ...                  ...    ...
# 23671             3     3450000        35.3           2017-04-14      1
# 23677             8     2450000        35.0           2018-10-26      1
# 23688            19     9200000       101.0           2019-04-01      3
# 23689            13     3550000        35.3           2018-02-28      1
# 23690             3     5500000        52.0           2018-07-19      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Таких строк около **3.5 тысяч**, это около **20%** от всех продаж, такие продажи можно считать быстрыми. Еще раз построим гистограмму для среза данных.

# %%
# задаем размер графика
plt.figure(figsize=(8,6))

# строим гистограмму для данных со сроками продажи менее 500 дней
good_data.loc[good_data['days_exposition'] < 500, 'days_exposition'].plot(kind='hist', 
                                                                          bins=100)

# обозначим медиану для этого среза данных
plt.axvline(good_data.loc[good_data['days_exposition'] < 500, 'days_exposition'].median(), 
            linestyle = '--',
            color = 'r')

# задаем названия графика
plt.title('Гистограмма количества дней размещения объявления по срезу данных')

# задаем подпись оси x
plt.xlabel('Количество дней размещения объявления')

# задаем подпись оси y
plt.ylabel('Кол-во квартир')

# выводим получившийся график
plt.show();

# %% [markdown]
# У нас есть два пика, один около **40 дней** и около **60 дней**, возможно, это связано с автоматическим снятием объявлений с публикации. У нас есть так же достаточно много продаж длительностью **больше 100 дней**, они-то и оказывают влияние на среднее и медиану.

# %% [markdown]
# Теперь оценим, какие факторы больше всего влияют на общую стоимость объекта. Изучим, зависит ли цена от:
# * общей площади;
# * жилой площади;
# * площади кухни;
# * количества комнат;
# * этажа, на котором расположена квартира (первый, последний, другой);
# * даты размещения (день недели, месяц, год).
#
# <a id='chapter_22'></a>Для начала для количественных переменных мы можем посчитать корреляцию с ценой.

# %%
# считаем корреляцию между ценой и общей площадью
good_data['last_price'].corr(good_data['total_area'])
# Out:
# 0.7323848687726107

# %%
# считаем корреляцию между ценой и жилой площадью
good_data['last_price'].corr(good_data['living_area'])
# Out:
# 0.6164941738756987

# %%
# считаем корреляцию между ценой и площадью кухни
good_data['last_price'].corr(good_data['kitchen_area'])
# Out:
# 0.5202904319241124

# %%
# считаем корреляцию между ценой и количеством комнат
good_data['last_price'].corr(good_data['rooms'])
# Out:
# 0.4686504405048508

# %%
# считаем корреляцию между ценой и этажом
good_data['last_price'].corr(good_data['floor'])
# Out:
# 0.12085330651651918

# %% [markdown]
# Видим, что сильнее всего на цену влияет общая площадь квартиры и меньше всего этаж расположения квартиры. Построим графики для каждого параметра.

# %%
# построим график scatter для оценки зависимости цены от общей площади:
good_data.plot(x='last_price', 
               y='total_area',
               kind='scatter', 
               title='Зависимость цены от общей площади',
               figsize=(8,6))

# задаем подпись оси x
plt.xlabel('Цена продажи объекта недвижимости')

# задаем подпись оси y
plt.ylabel('Общая площадь')

# выводим получившийся график
plt.show();

# %%
# построим график scatter для оценки зависимости цены от жилой площади:
good_data.plot(x='last_price', 
               y='living_area', 
               kind='scatter', 
               title='Зависимость цены от жилой площади',
               figsize=(8,6))

# задаем подпись оси x
plt.xlabel('Цена продажи объекта недвижимости')

# задаем подпись оси y
plt.ylabel('Жилая площадь')

# выводим получившийся график
plt.show();

# %%
# построим график scatter для оценки зависимости цены от площади кухни:
good_data.plot(x='last_price', 
               y='kitchen_area',
               kind='scatter', 
               title='Зависимость цены от площади кухни',
               figsize=(8,6))

# задаем подпись оси x
plt.xlabel('Цена продажи объекта недвижимости')

# задаем подпись оси y
plt.ylabel('Площадь кухни')

# выводим получившийся график
plt.show();

# %% [markdown]
# Из этих трех графиков можно сделать вывод, что больше всего на цену влияет параметр **total_area**, т.к. разброс наиболее близок к диагональной линии (т.е. к положительной корреляции), **living_area** так же влияет на цену, но меньше, а **kitchen_area** еще меньше.

# %% [markdown]
# <a id='chapter_23'></a>Теперь изучим зависимость цены от категориальных переменных с помощью графиков.

# %%
# построим столбчатую диаграмму по медианным значениям цены для каждого количества комнат:
good_data.pivot_table(index='rooms', 
                      values='last_price', 
                      aggfunc='median').plot(kind='bar', 
                                             title='Зависимость цены от количества комнат',
                                             figsize=(8,6),
                                             legend=False)

# задаем подпись оси x
plt.xlabel('Количество комнат')

# задаем подпись оси y
plt.ylabel('Цена продажи объекта недвижимости')

# выводим получившийся график
plt.show();

# %% [markdown]
# Видим, что количество комнат влияет на цену, но это связано, скорее всего, больше с площадью квартиры, т.к. обычно чем больше площадь, тем больше комнат.

# %%
# построим столбчатую диаграмму по медианным значениям цены для каждого года публикации:
good_data.pivot_table(index='year_exposition', 
                      values='last_price', 
                      aggfunc='median').plot(kind='bar', 
                                             color='orange', 
                                             title='Зависимость цены от года публикации',
                                             figsize=(8,6),
                                             legend=False);

# задаем подпись оси x
plt.xlabel('Год публикации')

# задаем поворот подписей значений оси x
plt.xticks(rotation=45)

# задаем подпись оси y
plt.ylabel('Цена продажи объекта недвижимости')

# выводим получившийся график
plt.show()

# построим столбчатую диаграмму по медианным значениям цены для каждого месяца публикации:
good_data.pivot_table(index='num_month_exposition', 
                      values='last_price', 
                      aggfunc='median').plot(kind='bar', 
                                             color='green', 
                                             title='Зависимость цены от месяца публикации',
                                             figsize=(8,6),
                                             legend=False)

# задаем подпись оси x
plt.xlabel('Месяц публикации')

# задаем подпись оси y
plt.ylabel('Цена продажи объекта недвижимости')

# выводим получившийся график
plt.show()

# построим столбчатую диаграмму по медианным значениям цены для каждого дня публикации:
good_data.pivot_table(index='num_day_exposition', 
                      values='last_price', 
                      aggfunc='median').plot(kind='bar',
                                             color='purple', 
                                             title='Зависимость цены от дня публикации',
                                             figsize=(8,6),
                                             legend=False)

# задаем подпись оси x
plt.xlabel('День публикации')

# задаем подпись оси y
plt.ylabel('Цена продажи объекта недвижимости')

# выводим получившийся график
plt.show();

# %% [markdown]
# Здесь можем видеть, что день и месяц размещения объявления очень слабо влияют на цену. А вот год влияет, **в 2014 году** медианная стоимость квартиры была намного выше, чем в последующих годах. До 2018 года был сильный спад в цене, а вот **с 2017 года** цена снова стала расти.

# %%
# построим столбчатую диаграмму по медианным значениям цены для каждого типа этажа:
good_data.pivot_table(index='type_of_floor', 
                      values='last_price',
                      aggfunc='median').plot(kind='bar', 
                                             title='Зависимость цены от типа этажа',
                                             figsize=(8,6),
                                             legend=False)

# задаем подпись оси x
plt.xlabel('Тип этажа')

# задаем поворот подписей значений оси x
plt.xticks(rotation=45)

# задаем подпись оси y
plt.ylabel('Цена продажи объекта недвижимости')

# выводим получившийся график
plt.show();

# %% [markdown]
# Видим, то квартиры на **первом этаже** стоят дешевле, чем на последнем и других этажах. Медианная цена продажи выше на других этажах (все этажи кроме первого и последнего). Отсюда можно сделать вывод, что люди предпочитают, в основном, квартиры не на крайних этажах.

# %% [markdown]
# <a id='chapter_24'></a>Теперь посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра. Для начала найдем количество уникальных значений в столбце **locality_name** и выведем первые 10 строк.

# %%
# считаем кол-во уникальных значений в столбце и выводим первые 10 строк
good_data['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург    14246
# Мурино               590
# Кудрово              471
# Шушары               440
# Всеволожск           395
# Пушкин               346
# Колпино              337
# Парголово            326
# Гатчина              305
# Выборг               232
# Name: locality_name, dtype: int64

# %% [markdown]
# Теперь из всех данных выберем только те, что относятся к этим 10-ти населенным пунктам.

# %%
# создадим список с названиями населенных пунктов, полученных ранее
cities = ['Санкт-Петербург', 'Мурино', 'Кудрово', 'Шушары', 'Всеволожск','Пушкин','Колпино', 'Парголово','Гатчина', 'Выборг']

# сделаем срез данных, оставив только города из списка
# затем сгруппируем по столбцу locality_name и найдем медианную цену по столбцу meter_price
price_per_meter = good_data.query('locality_name in @cities').groupby('locality_name')['meter_price'].median()

# выводим получившуюся таблицу
price_per_meter
# Out:
# locality_name
# Всеволожск          65789.0
# Выборг              58357.0
# Гатчина             67796.0
# Колпино             74722.0
# Кудрово             95762.0
# Мурино              86175.0
# Парголово           91779.5
# Пушкин              98915.5
# Санкт-Петербург    102678.0
# Шушары              76876.0
# Name: meter_price, dtype: float64

# %% [markdown]
# Построим барплот по полученным значениям.

# %%
# строим столбчатый график по отсортированным по убыванию значениям
(price_per_meter.sort_values(ascending=False)
               .plot(kind='bar', 
                     title='Распределение цены за квадратный метр по населенным пунктам',
                     figsize=(8,6),
                     legend=False))

# задаем подпись оси x
plt.xlabel('Населенный пункт')

# задаем поворот подписей значений оси x
plt.xticks(rotation=45)

# задаем подпись оси y
plt.ylabel('Цена за квадратный метр')

# выводим получившийся график
plt.show();

# %% [markdown]
# Населенные пункты с самой высокой стоимостью квадратного метра - это **Санкт-Петербург**, **Пушкин** и **Кудрово** (около 100 тысяч рублей за квадратный метр). Населенный пункт с самой низкой стоимостью квадратного метра - это **Выборг** (58 тысяч за кавдратный метр)

# %% [markdown]
# <a id='chapter_25'></a>Теперь вычислим среднюю цену каждого километра в Санкт-Петербурге.

# %%
# создадим отдельную таблицу со строками только для Санкт-Петербурга
data_spb = good_data.copy().loc[good_data['locality_name'] == "Санкт-Петербург"]

# выводим получившуюся таблицу
data_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 2            10     5196000        56.0           2015-08-20      2
# 4             2    10000000       100.0           2018-06-19      2
# 7             5     7915000        71.6           2019-04-18      2
# 9            18     5400000        61.0           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 2            2.60             5        34.30      4         False   False
# 4            3.03            14        32.00     13         False   False
# 7            2.60            24        42.44     22         False   False
# 9            2.50             9        43.60      7         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Добавим в таблицу столбец с ценой за каждый километр от центра города.

# %%
# создаем новый столбец и присваиваем ему значения общей цены/расстояние до центра в км
data_spb['price_meter_spb'] = data_spb['last_price']/data_spb['city_centers_kms']

# %% [markdown]
# Сгруппируем таблицу по столбцу расстояния до центра города и посчитаем медианную цену каждого километра.

# %%
# группируем таблицу по столбцу city_centers_kms, считаем медиану по столбцу price_meter_spb 
# и сортируем значения по убыванию
price_per_meter_spb = (data_spb.groupby('city_centers_kms')['price_meter_spb']
                               .median()
                               .sort_values(ascending=False))

# строим столбчатую диаграмму по полученным значениям
price_per_meter_spb.plot(kind='bar',
                         title='Распределение цены за квадратный метр по удаленности от центра',
                         figsize=(8,6),
                         legend=False)

# задаем подпись оси x
plt.xlabel('Удаленность от центра, км')

# задаем подпись оси y
plt.ylabel('Цена за квадратный метр')

# выводим получившийся график
plt.show();

# %% [markdown]
# Видим, что самый дорогой километр - это **первый километр** от центра города, почти в два раза дешевле - **второй километр**. Цена каждого километра постепенно уменьшается до **10 километра**. Дальше 10-ти километров от центра города цена меняется достаточно незначительно.

# %% [markdown]
# <div style = "border:solid green 2px; padding:20px">
#
# На данном шаге изучили основные параметры объектов, определили насколько быстро продавались квартиры - медианный срок продажи - <b>84 дня</b>.
#
# Рассмотрели какие факторы больше всего влияют на цену продажи. Определили, что наиболее сильная корреляция с ценой квартиры у <b>общей площади квартиры</b>, значит, этот параметр сильнее всего влияет на цену.
#
# Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Самый дорогой квадратный метр в городах <b>Пушкин и Санкт-Петербург</b>, самый дешевый - в <b>Выборге</b>.
#
# Определили среднюю цену одного километра в Санкт-Петербурге, самый дорогой километр - <b>первый от центра города</b>, его цена в несколько раз превышает последующие километры.
# <div/>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <div style = "border:solid green 3px; padding:20px">
#
# <a id='chapter_26'></a>Целью проекта было - выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
# В ходе выполнения проекта на стадии предобработки данных были заполнены все пропущенные значения там, где это возможно. А так же были устранены неявные дубликаты и аномальные значения в каждом столбце. Было определено, что в исходных данных присутствуют квартиры люкс-сегмента (т.е. очень большие и дорогие).
#
# Выяснили, что большинство квартир имеют <b>1-2 комнаты</b>, общую площадь <b>от 30 до 50 кв.м метров</b>, средняя цена варьируется <b>от 3,5 до 6 млн.рублей</b>. Расположено большинство квартир преимущественно <b>с 1 по 5 этаж</b>, а дома, в основном, <b>5-ти и 9-ти этажные</b>.
#
# Объявления публикуются в основном в <b>будние дни</b>. В летние месяцы, а так же в декабре, январе и мае объявлений меньше.
#
# Рассмотрели какие факторы больше всего влияют на цену продажи и определили, что <b>общая площадь квартиры</b> сильнее всего влияет на цену. Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Самый дорогой квадратный метр в городах <b>Пушкин и Санкт-Петербург</b>, самый дешевый - в <b>Выборге</b>.
#
# Определили среднюю цену одного километра в Санкт-Петербурге, самый дорогой километр - <b>первый от центра города</b>, его цена в несколько раз превышает последующие километры.
#
# <div/>
